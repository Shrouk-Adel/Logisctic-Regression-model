# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input_array=np.array([1,2,3])
exp_array=np.exp(input_array)

print(f"input array : {input_array}")
print(f'exp array : {exp_array}')
# Out:
# input array : [1 2 3]
# exp array : [ 2.71828183  7.3890561  20.08553692]

# %%
def sigmoid_function (z):
    # g= sigmoid(z)
    g=1/(1+np.exp(-z))
    return g

# %%
# lets see what is the output of the function
z_temp=np.arange(-10,11)
y=sigmoid_function(z_temp)
print(y)
# Out:
# [4.53978687e-05 1.23394576e-04 3.35350130e-04 9.11051194e-04
#  2.47262316e-03 6.69285092e-03 1.79862100e-02 4.74258732e-02
#  1.19202922e-01 2.68941421e-01 5.00000000e-01 7.31058579e-01
#  8.80797078e-01 9.52574127e-01 9.82013790e-01 9.93307149e-01
#  9.97527377e-01 9.99088949e-01 9.99664650e-01 9.99876605e-01
#  9.99954602e-01]

# %%
# plot z vs sigmoid(z)
fig,ax=plt.subplots(1,1,figsize=(8,4))
ax.plot(z_temp,y,c='b')
ax.set_title('sigmoid function')
ax.set_xlabel('z')
ax.set_ylabel('sigmoid(z)')
plt.show()

# %% [markdown]
# ### Logistic Regression Algorithms
# - g(z) = 1/(1+np.exp(-z)  ,  where Z = w . x + b

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

n=x_train.shape
w_in = np.zeros(n)
b_in = 0

print(w_in)
# Out:
# [0. 0. 0. 0. 0. 0.]

# %%
# Z = W .x + b
z = np.dot(w_in,x_train) + b_in
print(z)

y= sigmoid_function(z)
print (y)
# Out:
# 0.0
# 0.5
