# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### While reshaping, if you are unsure about the shape of any of the axis, just input -1. NumPy automatically calculates the shape when it sees a -1:
#
# a = np.array([3,6,9,12,18,24])
# - print('Three rows :','\n',np.reshape(a,(3,-1)))
# - print('Three columns :','\n',np.reshape(a,(-1,3)))
# Three rows :
# 1.
#  - [[ 3  6]
#  - [ 9 12]
#  - [18 24]]
# 2. Three columns :
#  - [[ 3  6  9]
#  - [12 18 24]]

# %% [markdown]
# ### Dataset

# %%
x = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1)
print(y)
print(x)
# Out:
# [[0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]]
# [[0.5 1.5]
#  [1.  1. ]
#  [1.5 0.5]
#  [3.  0.5]
#  [2.  2. ]
#  [1.  2.5]]

# %% [markdown]
# ### The camp="bwr" argument in the Python code you provided is used to specify the colormap
# for the scatter   plot. The bwr colormap is a sequential colormap that ranges from blue to white to red.
# This colormap is often used to represent data that has two different classes, such as the data in your example.

# %%
### plot data
plt.scatter(X[:, 0], X[:, 1], c=y[:, 0],marker='x', cmap='bwr')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
# plot sigmoid function over range (-10,11)
z=np.arange(-10,11)
def sigmoid_function (z):
    # g= sigmoid(z)
    g=1/(1+np.exp(-z))
    return g

fig,ax=plt.subplots(1,1,figsize=(8,4))
ax.plot(z,sigmoid_function(z))

ax.set_title('sigmoid function')
ax.set_xlabel('z')
ax.set_ylabel('sigmoid(z)')
plt.show()

# %% [markdown]
# ### Ploting decision boundary

# %% [markdown]
# Now, let's go back to our example to understand how the logistic regression model is making predictions.
#
# * Our logistic regression model has the form
#
#   $f(\mathbf{x}) = g(-3 + x_0+x_1)$
#
#
# * From what you've learnt above, you can see that this model predicts $y=1$ if $-3 + x_0+x_1 >= 0$
#
# Let's see what this looks like graphically. We'll start by plotting $-3 + x_0+x_1 = 0$, which is equivalent to $x_1 = 3 - x_0$.

# %%
x1=np.arange(0,4)
x2=3-x1

fig,ax=plt.subplots(1,1,figsize=(8,4))
ax.plot(x1,x2,c='r')
ax.scatter(X[:, 0], X[:, 1], c=y[:, 0],marker='x', cmap='bwr')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('deciscion boundary')
plt.show()
